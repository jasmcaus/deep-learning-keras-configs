# %%
from caer import preprocess
import numpy as np
import os
import time

# %%
DIR = r'F:\Dogs and Cats\Train'
classes = [i for i in os.listdir(DIR)]
IMG_SIZE = 224

# %%
since = time.time()
train = preprocess(DIR, classes, 'train', IMG_SIZE, train_size=12500)
end = time.time()
print(f'Took {end-since} seconds')
# Out:
# 10965 - Dogs
# 10966 - Dogs
# 10967 - Dogs
# 10968 - Dogs
# 10969 - Dogs
# 10970 - Dogs
# 10971 - Dogs
# 10972 - Dogs
# 10973 - Dogs
# 10974 - Dogs
# 10975 - Dogs
# 10976 - Dogs
# 10977 - Dogs
# 10978 - Dogs
# 10979 - Dogs
# 10980 - Dogs
# 10981 - Dogs
# 10982 - Dogs
# 10983 - Dogs
# 10984 - Dogs
# 10985 - Dogs
# 10986 - Dogs
# 10987 - Dogs
# 10988 - Dogs
# 10989 - Dogs
# 10990 - Dogs
# 10991 - Dogs
# 10992 - Dogs
# 10993 - Dogs
# 10994 - Dogs
# 10995 - Dogs
# 10996 - Dogs
# 10997 - Dogs
# 10998 - Dogs
# 10999 - Dogs
# 11000 - Dogs
# 11001 - Dogs
# 11002 - Dogs
# 11003 - Dogs
# 11004 - Dogs
# 11005 - Dogs
# 11006 - Dogs
# 11007 - Dogs
# 11008 - Dogs
# 11009 - Dogs
# 11010 - Dogs
# 11011 - Dogs
# 11012 - Dogs
# 11013 - Dogs
# 11014 - Dogs
# 11015 - Dogs
# 11016 - Dogs
# 11017 - Dogs
# 11018 - Dogs
# 11019 - Dogs
# 11020 - Dogs
# 11021 - Dogs
# 11022 - Dogs
# 11023 - Dogs
# 11024 - Dogs
# 11025 - Dogs
# 11026 - Dogs
# 11027 - Dogs
# 11028 - Dogs
# 11029 - Dogs
# 11030 - Dogs
# ...

# %%
print('Saving')
saveNumpy('train', train)
# Out:
# Executing
# Took 41.87373113632202s to save
# Took 42.07974624633789 seconds
